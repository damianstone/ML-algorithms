# %%
# Plynomial regression

# %% [markdown]
# ### Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

dataset = pd.read_csv('position_salaries.csv')

# features (from the second column since the first is the same as the second but as categorical)
x = dataset.iloc[:, 1:-1].values

# dependent variable (last column)
y = dataset.iloc[:, -1].values

# %% [markdown]
# ### Training the linear regression

# %%
from sklearn.linear_model import LinearRegression

regression_model_1 = LinearRegression()

regression_model_1.fit(x, y)
# Out:
# LinearRegression()

# %% [markdown]
# ### Training the polynomial regression

# %%
from sklearn.preprocessing import PolynomialFeatures

# to add an exponential to x1
# degree = 2 ->  get a new feature matrix containing [1, x, x^2], where 1 is the bias term, x is the original feature, and x^2 is the new polynomial feature
polynomial_regression = PolynomialFeatures(degree=2)
x_poly = polynomial_regression.fit_transform(x)

# new linear regression using the x_poly
regression_model_2 = LinearRegression()
regression_model_2.fit(x_poly, y)
# Out:
# LinearRegression()

# %% [markdown]
# ### Plot linear regression

# %%
plt.scatter(x, y, color="red")
plt.plot(x, regression_model_1.predict(x), color="blue")
plt.title("Linear regression")
plt.xlabel("Pisition level")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# ### Plot polynomial regression

# %%
plt.scatter(x, y, color="red")
plt.plot(x, regression_model_2.predict(x), color="blue")
plt.title("Plynomial regression")
plt.xlabel("Pisition level")
plt.ylabel("Salary")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 2
#       1 plt.scatter(x, y, color="red")
# ----> 2 plt.plot(x, regression_model_2.predict(x), color="blue")
#       3 plt.title("Plynomial regression")
#       4 plt.xlabel("Pisition level")
#
# File ~/Documents/Code/machine-learning/ML-course/venv-ML/lib/python3.9/site-packages/sklearn/linear_model/_base.py:354, in LinearModel.predict(self, X)
#     340 def predict(self, X):
#     341     """
#     342     Predict using the linear model.
#     343
#    (...)
#     352         Returns predicted values.
#     353     """
# --> 354     return self._decision_function(X)
#
# File ~/Documents/Code/machine-learning/ML-course/venv-ML/lib/python3.9/site-packages/sklearn/linear_model/_base.py:337, in LinearModel._decision_function(self, X)
#     334 def _decision_function(self, X):
#     335     check_is_fitted(self)
# --> 337     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     338     return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#
# File ~/Documents/Code/machine-learning/ML-course/venv-ML/lib/python3.9/site-packages/sklearn/base.py:588, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     585     out = X, y
#     587 if not no_val_X and check_params.get("ensure_2d", True):
# --> 588     self._check_n_features(X, reset=reset)
#     590 return out
#
# File ~/Documents/Code/machine-learning/ML-course/venv-ML/lib/python3.9/site-packages/sklearn/base.py:389, in BaseEstimator._check_n_features(self, X, reset)
#     386     return
#     388 if n_features != self.n_features_in_:
# --> 389     raise ValueError(
#     390         f"X has {n_features} features, but {self.__class__.__name__} "
#     391         f"is expecting {self.n_features_in_} features as input."
#     392     )
#
# ValueError: X has 1 features, but LinearRegression is expecting 3 features as input.

# %% [markdown]
# ### Predicting single values

# %%
# Predicting a new result with Linear Regression
regression_model_1.predict([[6.5]])

# Predicting a new result with Polynomial Regression
regression_model_2.predict(polynomial_regression.fit_transform([[6.5]]))
